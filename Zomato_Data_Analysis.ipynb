# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd # data manupulation
import numpy as np # math and stats
import matplotlib.pyplot as plt # visualization

# %% [markdown]
# # Reading CSV

# %%
orders = pd.read_csv("Orders.csv")
orders
# Out:
#     Order_ID Restaurant_ID           Order_Date  Expected_Delivery_Time  \
# 0      O0001          R079  2023-02-27 08:00:00                      26
# 1      O0002          R010  2023-01-09 18:00:00                      35
# 2      O0003          R055  2023-08-08 12:00:00                      29
# 3      O0004          R072  2023-02-26 22:00:00                      35
# 4      O0005          R097  2023-06-26 12:00:00                      33
# ..       ...           ...                  ...                     ...
# 995    O0996          R072  2023-08-02 18:00:00                      32
# 996    O0997          R071  2023-10-10 00:00:00                      39
# 997    O0998          R010  2023-07-31 06:00:00                      45
# 998    O0999          R100  2023-03-06 12:00:00                      34
# 999    O1000          R066  2023-09-01 20:00:00                      42
#
#      Actual_Delivery_Time  Total_Amount Order_Status Payment_Method  \
# ...

# %% [markdown]
# # First 5 orders

# %%
orders.head()
# Out:
#   Order_ID Restaurant_ID           Order_Date  Expected_Delivery_Time  \
# 0    O0001          R079  2023-02-27 08:00:00                      26
# 1    O0002          R010  2023-01-09 18:00:00                      35
# 2    O0003          R055  2023-08-08 12:00:00                      29
# 3    O0004          R072  2023-02-26 22:00:00                      35
# 4    O0005          R097  2023-06-26 12:00:00                      33
#
#    Actual_Delivery_Time  Total_Amount Order_Status Payment_Method  \
# 0                    29        731.48    Cancelled    Credit Card
# 1                    40        461.67    Cancelled            UPI
# 2                    28        557.85    Cancelled           Cash
# 3                    42        209.42    Cancelled            UPI
# 4                    23        411.99    Cancelled           Cash
#
#           Dish_Name Customer_ID
# 0  Margherita Pizza        C187
# 1     Chicken Wings        C036
# 2    Egg Fried Rice        C179
# ...

# %% [markdown]
# # Last 5 orders

# %%
orders.tail()
# Out:
#     Order_ID Restaurant_ID           Order_Date  Expected_Delivery_Time  \
# 995    O0996          R072  2023-08-02 18:00:00                      32
# 996    O0997          R071  2023-10-10 00:00:00                      39
# 997    O0998          R010  2023-07-31 06:00:00                      45
# 998    O0999          R100  2023-03-06 12:00:00                      34
# 999    O1000          R066  2023-09-01 20:00:00                      42
#
#      Actual_Delivery_Time  Total_Amount Order_Status Payment_Method  \
# 995                    35        776.38    Completed    Net Banking
# 996                    39        840.76    Completed            UPI
# 997                    36        232.90    Completed           Cash
# 998                    46        811.29    Completed            UPI
# 999                    47        534.73    Completed    Net Banking
#
#             Dish_Name Customer_ID
# 995     Pasta Alfredo        C163
# 996      Paneer Tikka        C048
# ...

# %%
orders.shape  # 10 columns and 1K rows
# Out:
# (1000, 10)

# %%
orders.columns
# Out:
# Index(['Order_ID', 'Restaurant_ID', 'Order_Date', 'Expected_Delivery_Time',
#        'Actual_Delivery_Time', 'Total_Amount', 'Order_Status',
#        'Payment_Method', 'Dish_Name', 'Customer_ID'],
#       dtype='object')

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                1000 non-null   object
#  1   Restaurant_ID           1000 non-null   object
#  2   Order_Date              1000 non-null   object
#  3   Expected_Delivery_Time  1000 non-null   int64
#  4   Actual_Delivery_Time    1000 non-null   int64
#  5   Total_Amount            1000 non-null   float64
#  6   Order_Status            1000 non-null   object
#  7   Payment_Method          1000 non-null   object
#  8   Dish_Name               1000 non-null   object
#  9   Customer_ID             1000 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 78.3+ KB

# %%
orders["Order_Date"] = pd.to_datetime(orders["Order_Date"]) # changing datatype

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                1000 non-null   object
#  1   Restaurant_ID           1000 non-null   object
#  2   Order_Date              1000 non-null   datetime64[ns]
#  3   Expected_Delivery_Time  1000 non-null   int64
#  4   Actual_Delivery_Time    1000 non-null   int64
#  5   Total_Amount            1000 non-null   float64
#  6   Order_Status            1000 non-null   object
#  7   Payment_Method          1000 non-null   object
#  8   Dish_Name               1000 non-null   object
#  9   Customer_ID             1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 78.3+ KB

# %% [markdown]
# # Count Plot of Various Months

# %%
orders["Month"] = orders["Order_Date"].dt.strftime("%B") # B - month , A - Day , Y - Year
month_counts = orders["Month"].value_counts()

plt.plot(month_counts.index, month_counts.values, color="green") 
plt.grid(color = "grey")
plt.xlabel("Months", color="blue")
plt.ylabel("Order Count", color="blue")
plt.title("Count of Orders by Month", color="red")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Reading CSV

# %%
customers = pd.read_csv("Customers.csv")
customers
# Out:
#     Customer_ID Customer_Location Customer_Age_Group  Customer_Rating  \
# 0          C001             Delhi              18-25              3.1
# 1          C002         Bangalore              36-45              4.3
# 2          C003             Delhi              26-35              4.6
# 3          C004            Mumbai              46-55              4.3
# 4          C005            Mumbai              36-45              3.2
# ..          ...               ...                ...              ...
# 195        C196              Pune              36-45              3.6
# 196        C197              Pune              46-55              4.4
# 197        C198             Delhi              46-55              4.3
# 198        C199         Bangalore              18-25              4.0
# 199        C200         Bangalore              36-45              3.6
#
#      Customer_Name
# 0      Rohan Joshi
# 1    Vivaan Khanna
# 2         Mira Rao
# 3     Aarav Sharma
# 4        Dev Patel
# ...

# %% [markdown]
# # Joining orders and customers table

# %%
ord_cus = pd.merge(left = orders , right = customers , on = "Customer_ID" , how = "inner")
ord_cus
# Out:
#     Order_ID Restaurant_ID          Order_Date  Expected_Delivery_Time  \
# 0      O0001          R079 2023-02-27 08:00:00                      26
# 1      O0002          R010 2023-01-09 18:00:00                      35
# 2      O0003          R055 2023-08-08 12:00:00                      29
# 3      O0004          R072 2023-02-26 22:00:00                      35
# 4      O0005          R097 2023-06-26 12:00:00                      33
# ..       ...           ...                 ...                     ...
# 995    O0996          R072 2023-08-02 18:00:00                      32
# 996    O0997          R071 2023-10-10 00:00:00                      39
# 997    O0998          R010 2023-07-31 06:00:00                      45
# 998    O0999          R100 2023-03-06 12:00:00                      34
# 999    O1000          R066 2023-09-01 20:00:00                      42
#
#      Actual_Delivery_Time  Total_Amount Order_Status Payment_Method  \
# ...

# %%
ord_cus.columns
# Out:
# Index(['Order_ID', 'Restaurant_ID', 'Order_Date', 'Expected_Delivery_Time',
#        'Actual_Delivery_Time', 'Total_Amount', 'Order_Status',
#        'Payment_Method', 'Dish_Name', 'Customer_ID', 'Month',
#        'Customer_Location', 'Customer_Age_Group', 'Customer_Rating',
#        'Customer_Name'],
#       dtype='object')

# %% [markdown]
# # Count of Orders by various Locations

# %%
location_counts = ord_cus["Customer_Location"].value_counts()

plt.bar(location_counts.index, location_counts.values, color="purple") 
plt.xlabel("Months", color="blue")
plt.ylabel("Order Count", color="blue")
plt.title("Count of Orders by various Locations", color="red")
plt.xticks(rotation=45)
plt.show()

# %%
orders["Payment_Method"]
# Out:
# 0      Credit Card
# 1              UPI
# 2             Cash
# 3              UPI
# 4             Cash
#           ...
# 995    Net Banking
# 996            UPI
# 997           Cash
# 998            UPI
# 999    Net Banking
# Name: Payment_Method, Length: 1000, dtype: object

# %% [markdown]
# # No of times by various Payment Methods

# %%
payment_counts = orders["Payment_Method"].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(payment_counts.values, labels=payment_counts.index, startangle=90, autopct='%1.1f%%')
plt.title("Distribution of Orders by Payment Method")
plt.legend(loc="best")
plt.show()

# %%
orders["Dish_Name"].unique()
# Out:
# array(['Margherita Pizza', 'Chicken Wings', 'Egg Fried Rice',
#        'Paneer Tikka', 'Veg Manchurian', 'Dal Makhani',
#        'Mutton Rogan Josh', 'Veg Thali', 'Paneer Butter Masala',
#        'Chicken Biryani', 'Garlic Naan', 'Tandoori Chicken',
#        'Masala Dosa', 'Chicken Shawarma', 'Butter Chicken', 'Fish Curry',
#        'Chole Bhature', 'Samosa Chaat', 'Pasta Alfredo', 'Hakka Noodles'],
#       dtype=object)

# %% [markdown]
# # Number of Orders by Dish Name

# %%
dish_counts = orders["Dish_Name"].value_counts()

plt.figure(figsize=(12, 6))
plt.bar(dish_counts.index, dish_counts.values, color='m', edgecolor='black')
plt.xlabel("Dish Name", color="blue")
plt.ylabel("Count", color="blue")
plt.title("Number of Orders by Dish Name", color="red")
plt.xticks(rotation=90) 
plt.show()
